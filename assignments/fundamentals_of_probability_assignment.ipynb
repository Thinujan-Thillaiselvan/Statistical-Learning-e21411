# %% [markdown]
# <a href="https://colab.research.google.com/github/Thinujan-Thillaiselvan/Statistical-Learning-e21411/blob/main/assignments/fundamentals_of_probability_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q1) The Probability of Shooting at a Target

# %% [markdown]
# A point is chosen at random from a disk of radius $10$. Let $A$ be the event that the point lies within $1$ unit of the boundary.
#
# 1. Model the experiment assuming the point is uniformly distributed with respect to area, and compute $P(A)$.
# 2. Model the experiment assuming the distance to the point from the center is chosen uniformly from $[0,10]$, and the direction is chosen independently and uniformly from $[0,2\pi)$ and compute $P(A)$.
# 3. Explain why the two answers differ.

# %%
from IPython.display import display, Math

# Part 1
display(Math(r"\textbf{(1)\ Uniform\ over\ area}"))
display(Math(r"P(A) = \frac{100\pi - 81\pi}{100\pi} = \frac{19}{100}"))

# Part 2
display(Math(r"\textbf{(2)\ Radius\ uniform\ in\ [0,10]}"))
display(Math(r"P(A) = \frac{10 - 9}{10} = \frac{1}{10}"))

# Part 3
display(Math(r"\textbf{(3)\ Explanation}"))
display(Math(r"\text{Uniform area gives more points near boundary, whereas uniform radius does not.}"))
# Out:
# $\displaystyle \textbf{(1)\ Uniform\ over\ area}$
# $\displaystyle P(A) = \frac{100\pi - 81\pi}{100\pi} = \frac{19}{100}$
# $\displaystyle \textbf{(2)\ Radius\ uniform\ in\ [0,10]}$
# $\displaystyle P(A) = \frac{10 - 9}{10} = \frac{1}{10}$
# $\displaystyle \textbf{(3)\ Explanation}$
# $\displaystyle \text{Uniform area gives more points near boundary, whereas uniform radius does not.}$

# %% [markdown]
# # Q2) Bertrand's Paradox

# %% [markdown]
# A chord of a circle is chosen “at random.” What is the probability that its length exceeds the side length of the inscribed equilateral triangle?
#
# Show that different mathematically natural models of “random chord” lead to different answers.

# %%
from IPython.display import display, Math

# Part 1
display(Math(r"\textbf{(1)\ Random\ endpoints\ on\ circumference}"))
display(Math(r"P = \frac{1}{3}"))

# Part 2
display(Math(r"\textbf{(2)\ Random\ radius\ and\ midpoint\ on\ it}"))
display(Math(r"P = \frac{1}{2}"))

# Part 3
display(Math(r"\textbf{(3)\ Random\ midpoint\ in\ circle}"))
display(Math(r"P = \frac{1}{4}"))

# Explanation
display(Math(r"\textbf{Explanation}"))
display(Math(r"\text{Different definitions of 'random chord' lead to different probability distributions.}"))
# Out:
# $\displaystyle \textbf{(1)\ Random\ endpoints\ on\ circumference}$
# $\displaystyle P = \frac{1}{3}$
# $\displaystyle \textbf{(2)\ Random\ radius\ and\ midpoint\ on\ it}$
# $\displaystyle P = \frac{1}{2}$
# $\displaystyle \textbf{(3)\ Random\ midpoint\ in\ circle}$
# $\displaystyle P = \frac{1}{4}$
# $\displaystyle \textbf{Explanation}$
# $\displaystyle \text{Different definitions of 'random chord' lead to different probability distributions.}$

# %% [markdown]
# #Q8) Probability of Being a Girl?

# %% [markdown]
# A family has two children. Assume each child is equally likely to be a boy or a girl, independently of the other.
#
# What is the probability that both children are girls, given that **at least one** of them is a girl?

# %%
from IPython.display import display, Math
# Given
display(Math(r"\text{Sample space: } \{BB,\ BG,\ GB,\ GG\}"))

# Condition
display(Math(r"\textbf{Given:\ at\ least\ one\ girl}"))
display(Math(r"\text{Possible outcomes: } \{BG,\ GB,\ GG\}"))

# Probability
display(Math(r"\textbf{Required probability}"))
display(Math(r"P(\text{both girls} \mid \text{at least one girl}) = \frac{1}{3}"))

# Explanation
display(Math(r"\textbf{Explanation}"))
display(Math(r"\text{Out of three equally likely cases with at least one girl, only one is GG.}"))
# Out:
# $\displaystyle \text{Sample space: } \{BB,\ BG,\ GB,\ GG\}$
# $\displaystyle \textbf{Given:\ at\ least\ one\ girl}$
# $\displaystyle \text{Possible outcomes: } \{BG,\ GB,\ GG\}$
# $\displaystyle \textbf{Required probability}$
# $\displaystyle P(\text{both girls} \mid \text{at least one girl}) = \frac{1}{3}$
# $\displaystyle \textbf{Explanation}$
# $\displaystyle \text{Out of three equally likely cases with at least one girl, only one is GG.}$

# %% [markdown]
# # Q9) Information Available in a Discrete Random Variable

# %% [markdown]
# A factory inspects a product and records its quality using two different coding systems.
#
# Each product falls into exactly one of the following four categories:
#
# * $G_1$: good quality, produced on Machine 1
# * $G_2$: good quality, produced on Machine 2
# * $D_1$: defective, produced on Machine 1
# * $D_2$: defective, produced on Machine 2
#
# Assume the sample space is
#
# $$
# \Omega=\{G_1,G_2,D_1,D_2\},
# $$
#
# with probabilities
#
# $$
# P(\{G_1\})=0.50,\qquad P(\{G_2\})=0.20,\qquad P(\{D_1\})=0.10,\qquad P(\{D_2\})=0.20.
# $$
#
# Define two discrete random variables on the same probability space:
#
# * $X$ records only whether the item is good or defective:
#   $$
#   X(G_1)=0,\quad X(G_2)=0,\quad X(D_1)=1,\quad X(D_2)=1.
#   $$
#
# * $Y$ records both quality and machine:
#   $$
#   Y(G_1)=1,\quad Y(G_2)=2,\quad Y(D_1)=3,\quad Y(D_2)=4.
#   $$
#
# Answer the following.
#
# 1. Write down the probability space $(\Omega,\mathfrak F,P)$, where $\mathfrak F=\mathfrak P(\Omega)$.
#
# 2. Compute the $\sigma$-algebra generated by $X$, namely $\sigma(X)$.
#
# 3. Compute the $\sigma$-algebra generated by $Y$, namely $\sigma(Y)$.
#
# 4. Show that $\sigma(X)\subseteq \sigma(Y)$, and explain why $Y$ contains more information than $X$.
#
# 5. Find the marginal distribution of $X$.
#
# 6. Find the marginal distribution of $Y$.
#
# 7. Compute the joint probabilities
#    $$
#    P(X=0,Y=1),\quad P(X=0,Y=2),\quad P(X=1,Y=3),\quad P(X=1,Y=4).
#    $$
#
# 8. Compute the conditional probabilities
#    $$
#    P(X=1\mid Y=3),\qquad P(X=1\mid Y=4),\qquad P(Y=3\mid X=1),\qquad P(Y=4\mid X=1).
#    $$
#
# 9. Interpret the difference between conditioning on $X$ and conditioning on $Y$.
#
# 10. Explain, in words, what information is available in $\sigma(X)$ but not in $\sigma(Y)$, and what information is available in $\sigma(Y)$ but not in $\sigma(X)$.
#
# 11. Give a Python based visualization of the model.
#
# 12. Find the marginal, joint, and conditional Shannon Entropy of $X$ and $Y$.

# %%
from IPython.display import display, Math


# (1)
display(Math(r"\textbf{(1)\ Probability\ Space}"))
display(Math(r"\Omega=\{G_1,G_2,D_1,D_2\},\quad \mathfrak{F}=\mathfrak{P}(\Omega)"))
display(Math(r"P(G_1)=0.5,\;P(G_2)=0.2,\;P(D_1)=0.1,\;P(D_2)=0.2"))

# (2)
display(Math(r"\textbf{(2)\ }\sigma(X)"))
display(Math(r"\sigma(X)=\{\emptyset,\Omega,\{G_1,G_2\},\{D_1,D_2\}\}"))

# (3)
display(Math(r"\textbf{(3)\ }\sigma(Y)"))
display(Math(r"\sigma(Y)=\mathfrak{P}(\Omega)"))

# (4)
display(Math(r"\textbf{(4)\ Relationship}"))
display(Math(r"\sigma(X)\subseteq\sigma(Y)"))
display(Math(r"\text{Y contains full info (quality + machine), X only quality}"))

# (5)
display(Math(r"\textbf{(5)\ Marginal\ of\ X}"))
display(Math(r"P(X=0)=0.7,\quad P(X=1)=0.3"))

# (6)
display(Math(r"\textbf{(6)\ Marginal\ of\ Y}"))
display(Math(r"P(Y=1)=0.5,\;P(Y=2)=0.2,\;P(Y=3)=0.1,\;P(Y=4)=0.2"))

# (7)
display(Math(r"\textbf{(7)\ Joint}"))
display(Math(r"P(0,1)=0.5,\;P(0,2)=0.2"))
display(Math(r"P(1,3)=0.1,\;P(1,4)=0.2"))

# (8)
display(Math(r"\textbf{(8)\ Conditional}"))
display(Math(r"P(X=1|Y=3)=1,\;P(X=1|Y=4)=1"))
display(Math(r"P(Y=3|X=1)=\frac{1}{3},\;P(Y=4|X=1)=\frac{2}{3}"))

# (9)
display(Math(r"\textbf{(9)\ Interpretation}"))
display(Math(r"\text{Conditioning on Y gives exact category}"))
display(Math(r"\text{Conditioning on X gives only good/defective}"))

# (10)
display(Math(r"\textbf{(10)\ Information}"))
display(Math(r"\text{σ(X): quality only}"))
display(Math(r"\text{σ(Y): quality + machine (more detailed)}"))

# (12) Entropy
display(Math(r"\textbf{(12)\ Entropy}"))
display(Math(r"H(X)=-(0.7\log_2 0.7 + 0.3\log_2 0.3)\approx0.88"))
display(Math(r"H(Y)=-(0.5\log_2 0.5 + 0.2\log_2 0.2 + 0.1\log_2 0.1 + 0.2\log_2 0.2)\approx1.76"))
display(Math(r"H(Y|X)=0.3\times H(\frac{1}{3},\frac{2}{3})\approx0.28"))
display(Math(r"I(X;Y)=H(Y)-H(Y|X)\approx1.48"))

import matplotlib.pyplot as plt

labels = ['G1','G2','D1','D2']
probs = [0.5,0.2,0.1,0.2]

plt.bar(labels, probs)
plt.xlabel("Categories")
plt.ylabel("Probability")
plt.title("Distribution of Y (Full Information)")
plt.show()
# Out:
# $\displaystyle \textbf{(1)\ Probability\ Space}$
# $\displaystyle \Omega=\{G_1,G_2,D_1,D_2\},\quad \mathfrak{F}=\mathfrak{P}(\Omega)$
# $\displaystyle P(G_1)=0.5,\;P(G_2)=0.2,\;P(D_1)=0.1,\;P(D_2)=0.2$
# $\displaystyle \textbf{(2)\ }\sigma(X)$
# $\displaystyle \sigma(X)=\{\emptyset,\Omega,\{G_1,G_2\},\{D_1,D_2\}\}$
# $\displaystyle \textbf{(3)\ }\sigma(Y)$
# $\displaystyle \sigma(Y)=\mathfrak{P}(\Omega)$
# $\displaystyle \textbf{(4)\ Relationship}$
# $\displaystyle \sigma(X)\subseteq\sigma(Y)$
# $\displaystyle \text{Y contains full info (quality + machine), X only quality}$
# $\displaystyle \textbf{(5)\ Marginal\ of\ X}$
# $\displaystyle P(X=0)=0.7,\quad P(X=1)=0.3$
# $\displaystyle \textbf{(6)\ Marginal\ of\ Y}$
# $\displaystyle P(Y=1)=0.5,\;P(Y=2)=0.2,\;P(Y=3)=0.1,\;P(Y=4)=0.2$
# $\displaystyle \textbf{(7)\ Joint}$
# $\displaystyle P(0,1)=0.5,\;P(0,2)=0.2$
# $\displaystyle P(1,3)=0.1,\;P(1,4)=0.2$
# $\displaystyle \textbf{(8)\ Conditional}$
# $\displaystyle P(X=1|Y=3)=1,\;P(X=1|Y=4)=1$
# $\displaystyle P(Y=3|X=1)=\frac{1}{3},\;P(Y=4|X=1)=\frac{2}{3}$
# $\displaystyle \textbf{(9)\ Interpretation}$
# $\displaystyle \text{Conditioning on Y gives exact category}$
# $\displaystyle \text{Conditioning on X gives only good/defective}$
# $\displaystyle \textbf{(10)\ Information}$
# $\displaystyle \text{σ(X): quality only}$
# $\displaystyle \text{σ(Y): quality + machine (more detailed)}$
# $\displaystyle \textbf{(12)\ Entropy}$
# $\displaystyle H(X)=-(0.7\log_2 0.7 + 0.3\log_2 0.3)\approx0.88$
# $\displaystyle H(Y)=-(0.5\log_2 0.5 + 0.2\log_2 0.2 + 0.1\log_2 0.1 + 0.2\log_2 0.2)\approx1.76$
# $\displaystyle H(Y|X)=0.3\times H(\frac{1}{3},\frac{2}{3})\approx0.28$
# $\displaystyle I(X;Y)=H(Y)-H(Y|X)\approx1.48$

# %% [markdown]
# # Q10) Information Available in Continuous Random Varaibles

# %% [markdown]
# A chemical plant monitors each production run using two different measurement systems.
#
# For a given run, let
#
# * $T$ be the deviation of the reactor temperature from target, measured in standardized units,
# * $P$ be the deviation of the reactor pressure from target, also measured in standardized units.
#
# Assume that $(T,P)$ is jointly continuous, with independent normal components:
#
# $$
# T \sim N(0,1), \qquad P \sim N(0,4),
# $$
#
# and $T$ and $P$ are independent.
#
# Let the underlying probability space be
#
# $$
# \Omega=\mathbb R^2, \qquad \mathfrak F=\mathfrak B(\mathbb R^2),
# $$
#
# and let $P$ be the probability measure induced by the joint density
#
# $$
# f_{T,P}(t,p)=\frac{1}{4\pi}\exp\left(-\frac{t^2}{2}-\frac{p^2}{8}\right), \qquad (t,p)\in\mathbb R^2.
# $$
#
# Define two random variables on the same probability space:
#
# * $X:\Omega\to\mathbb R$ by
#   $$
#   X(t,p)=t,
#   $$
#   so that $X$ records only the reactor temperature deviation;
#
# * $Y:\Omega\to\mathbb R^2$ by
#   $$
#   Y(t,p)=(t,p),
#   $$
#   so that $Y$ records the full sensor state: both temperature and pressure deviations.
#
# Answer the following.
#
# 1. Write down the probability space $(\Omega,\mathfrak F,P)$ explicitly.
#
# 2. Compute the $\sigma$-algebra generated by $X$, namely $\sigma(X)$.
#
# 3. Compute the $\sigma$-algebra generated by $Y$, namely $\sigma(Y)$.
#
# 4. Show that
#    $$
#    \sigma(X)\subseteq \sigma(Y),
#    $$
#    and explain why $Y$ contains more information than $X$.
#
# 5. Find the marginal density of $X$.
#
# 6. Find the marginal density of $Y$.
#
# 7. Compute the following probabilities:
#    $$
#    P(X\leq 0), \qquad P(X>1), \qquad P(Y\in (-\infty,0]\times\mathbb R), \qquad P(Y\in [ -1,1]\times[-2,2]).
#    $$
#
# 8. Compute the conditional distribution of $X$ given $Y=(t,p)$.
#
# 9. Compute the conditional distribution of $Y$ given $X=t$.
#
# 10. Explain, in words, what is known when one conditions on $X$ and what additional information becomes available when one conditions on $Y$.
#
# 11. Show that
#     $$
#     X=\pi_1\circ Y,
#     $$
#     where $\pi_1(t,p)=t$, and explain why this implies that $X$ is a measurable function of $Y$.
#
# 12. Give a Python-based visualization of the model, for example by plotting:
#
# * the joint density of $Y=(T,P)$ as a contour plot or heat map;
# * the marginal density of $X$;
# * and a diagram illustrating that $\sigma(X)$ is coarser than $\sigma(Y)$.
#
# 13. Compute the differential entropy of $X$:
#
# $$
# h(X)=-\int_{\mathbb R} f_X(x)\ln f_X(x)\,dx.
# $$
#
# 14. Compute the differential entropy of $Y$:
#
# $$
# h(Y)=-\int_{\mathbb R^2} f_Y(t,p)\ln f_Y(t,p)\,dt\,dp.
# $$
#
# 15. Compute the conditional differential entropy
#
# $$
# h(Y|X),
# $$
#
# and interpret it physically.
#
# 16. Discuss what happens to
#
# $$
# h(X|Y)
# $$
#
# in this model, and explain why the continuous case differs from the discrete case when one random variable is completely determined by the other.

# %%
from IPython.display import display, Math
import numpy as np
import matplotlib.pyplot as plt


# (1)
display(Math(r"\textbf{(1)\ Probability\ Space}"))
display(Math(r"\Omega=\mathbb{R}^2,\quad \mathfrak{F}=\mathfrak{B}(\mathbb{R}^2)"))
display(Math(r"f_{T,P}(t,p)=\frac{1}{4\pi}e^{-\frac{t^2}{2}-\frac{p^2}{8}}"))

# (2)
display(Math(r"\textbf{(2)\ }\sigma(X)"))
display(Math(r"\sigma(X)=\{A\times\mathbb{R}:A\in\mathfrak{B}(\mathbb{R})\}"))

# (3)
display(Math(r"\textbf{(3)\ }\sigma(Y)"))
display(Math(r"\sigma(Y)=\mathfrak{B}(\mathbb{R}^2)"))

# (4)
display(Math(r"\textbf{(4)\ Relationship}"))
display(Math(r"\sigma(X)\subseteq\sigma(Y)"))
display(Math(r"\text{Y contains more information (T and P), X only T}"))

# (5)
display(Math(r"\textbf{(5)\ Marginal\ of\ X}"))
display(Math(r"f_X(t)=\frac{1}{\sqrt{2\pi}}e^{-t^2/2}"))

# (6)
display(Math(r"\textbf{(6)\ Marginal\ of\ Y}"))
display(Math(r"f_Y(t,p)=\frac{1}{4\pi}e^{-t^2/2-p^2/8}"))

# (7)
display(Math(r"\textbf{(7)\ Probabilities}"))
display(Math(r"P(X\le0)=0.5"))
display(Math(r"P(X>1)=1-\Phi(1)\approx0.1587"))
display(Math(r"P(Y\in(-\infty,0]\times\mathbb{R})=0.5"))
display(Math(r"P(Y\in[-1,1]\times[-2,2])\approx0.466"))

# (8)
display(Math(r"\textbf{(8)\ Conditional\ } X|Y"))
display(Math(r"X|Y=(t,p)=t"))

# (9)
display(Math(r"\textbf{(9)\ Conditional\ } Y|X"))
display(Math(r"Y|X=t=(t,P),\quad P\sim N(0,4)"))

# (10)
display(Math(r"\textbf{(10)\ Interpretation}"))
display(Math(r"\text{Conditioning on X gives only temperature}"))
display(Math(r"\text{Conditioning on Y gives full system state}"))

# (11)
display(Math(r"\textbf{(11)\ Measurability}"))
display(Math(r"X=\pi_1\circ Y,\quad \pi_1(t,p)=t"))

# (12) Visualization code (printed explanation)
display(Math(r"\textbf{(12)}"))
# Grid
t = np.linspace(-4,4,200)
p = np.linspace(-8,8,200)
T, P = np.meshgrid(t,p)

# Joint density
Z = (1/(4*np.pi))*np.exp(-T**2/2 - P**2/8)

# Plot
plt.contourf(T,P,Z)
plt.title("Joint Density of (T,P)")
plt.xlabel("Temperature")
plt.ylabel("Pressure")
plt.colorbar()
plt.show()

# (13)
display(Math(r"\textbf{(13)\ Entropy\ of\ X}"))
display(Math(r"h(X)=\frac{1}{2}\ln(2\pi e)\approx1.42"))

# (14)
display(Math(r"\textbf{(14)\ Entropy\ of\ Y}"))
display(Math(r"h(Y)=\frac{1}{2}\ln((2\pi e)^2\cdot4)\approx2.84"))

# (15)
display(Math(r"\textbf{(15)\ Conditional\ Entropy}"))
display(Math(r"h(Y|X)=\frac{1}{2}\ln(8\pi e)\approx1.42"))

# (16)
display(Math(r"\textbf{(16)\ Special\ Case}"))
display(Math(r"h(X|Y)=-\infty"))
display(Math(r"\text{Continuous exact knowledge ⇒ infinite precision}"))
# Out:
# $\displaystyle \textbf{(1)\ Probability\ Space}$
# $\displaystyle \Omega=\mathbb{R}^2,\quad \mathfrak{F}=\mathfrak{B}(\mathbb{R}^2)$
# $\displaystyle f_{T,P}(t,p)=\frac{1}{4\pi}e^{-\frac{t^2}{2}-\frac{p^2}{8}}$
# $\displaystyle \textbf{(2)\ }\sigma(X)$
# $\displaystyle \sigma(X)=\{A\times\mathbb{R}:A\in\mathfrak{B}(\mathbb{R})\}$
# $\displaystyle \textbf{(3)\ }\sigma(Y)$
# $\displaystyle \sigma(Y)=\mathfrak{B}(\mathbb{R}^2)$
# $\displaystyle \textbf{(4)\ Relationship}$
# $\displaystyle \sigma(X)\subseteq\sigma(Y)$
# $\displaystyle \text{Y contains more information (T and P), X only T}$
# $\displaystyle \textbf{(5)\ Marginal\ of\ X}$
# $\displaystyle f_X(t)=\frac{1}{\sqrt{2\pi}}e^{-t^2/2}$
# $\displaystyle \textbf{(6)\ Marginal\ of\ Y}$
# $\displaystyle f_Y(t,p)=\frac{1}{4\pi}e^{-t^2/2-p^2/8}$
# $\displaystyle \textbf{(7)\ Probabilities}$
# $\displaystyle P(X\le0)=0.5$
# $\displaystyle P(X>1)=1-\Phi(1)\approx0.1587$
# $\displaystyle P(Y\in(-\infty,0]\times\mathbb{R})=0.5$
# $\displaystyle P(Y\in[-1,1]\times[-2,2])\approx0.466$
# $\displaystyle \textbf{(8)\ Conditional\ } X|Y$
# $\displaystyle X|Y=(t,p)=t$
# $\displaystyle \textbf{(9)\ Conditional\ } Y|X$
# $\displaystyle Y|X=t=(t,P),\quad P\sim N(0,4)$
# $\displaystyle \textbf{(10)\ Interpretation}$
# $\displaystyle \text{Conditioning on X gives only temperature}$
# $\displaystyle \text{Conditioning on Y gives full system state}$
# $\displaystyle \textbf{(11)\ Measurability}$
# $\displaystyle X=\pi_1\circ Y,\quad \pi_1(t,p)=t$
# $\displaystyle \textbf{(12)}$
# $\displaystyle \textbf{(13)\ Entropy\ of\ X}$
# $\displaystyle h(X)=\frac{1}{2}\ln(2\pi e)\approx1.42$
# $\displaystyle \textbf{(14)\ Entropy\ of\ Y}$
# $\displaystyle h(Y)=\frac{1}{2}\ln((2\pi e)^2\cdot4)\approx2.84$
# $\displaystyle \textbf{(15)\ Conditional\ Entropy}$
# $\displaystyle h(Y|X)=\frac{1}{2}\ln(8\pi e)\approx1.42$
# $\displaystyle \textbf{(16)\ Special\ Case}$
# $\displaystyle h(X|Y)=-\infty$
# $\displaystyle \text{Continuous exact knowledge ⇒ infinite precision}$
